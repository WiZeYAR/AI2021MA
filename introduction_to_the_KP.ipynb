# %% [markdown]
# # Lab 2 MA course in Artificial Intelligence 2021/2021

# %%
# !rm -r AI2021
# !git clone https://github.com/UmbertoJr/AI2021.git
# Out:
# Cloning into 'AI2021'...
# remote: Enumerating objects: 231, done.
# remote: Counting objects: 100% (231/231), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 231 (delta 121), reused 177 (delta 69), pack-reused 0
# Receiving objects: 100% (231/231), 414.23 KiB | 9.21 MiB/s, done.
# Resolving deltas: 100% (121/121), done.

# %% [markdown]
# ## Knapsack Problem

# %%
from AI2021.IO_manager.io_kp import KP_Instance_Creator, distributions

ic = KP_Instance_Creator("random")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# random
# collected 26.0% of the volume

# %%
for distr in distributions:
  print(distr)
# Out:
# uncorrelated
# weakly_correlated
# strongly_correlated
# inverse_weakly_correlated
# inverse_strongly_correlated
# multiple_strongly_correlated
# multiple_inverse_strongly_correlated
# circle

# %%
ic = KP_Instance_Creator("uncorrelated")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# uncorrelated
# collected 68.0% of the volume

# %%
ic = KP_Instance_Creator("weakly_correlated")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# uncorrelated
# collected 68.0% of the volume

# %%
ic = KP_Instance_Creator("strongly_correlated")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# strongly_correlated
# collected 68.0% of the volume

# %%
ic = KP_Instance_Creator("inverse_weakly_correlated")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# inverse_weakly_correlated
# collected 66.0% of the volume

# %%
ic = KP_Instance_Creator("inverse_strongly_correlated")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# inverse_strongly_correlated
# collected 80.0% of the volume

# %%
ic = KP_Instance_Creator("multiple_strongly_correlated")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# multiple_strongly_correlated
# collected 68.0% of the volume

# %%
ic = KP_Instance_Creator("multiple_inverse_strongly_correlated")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# multiple_inverse_strongly_correlated
# collected 79.0% of the volume

# %%
ic = KP_Instance_Creator("circle")
ic.plot_data_scatter()
ic.plot_data_distribution()
# Out:
# circle
# collected 60.0% of the volume

# %% [markdown]
# ## solving the KP
